# %%
import pandas as pd
import numpy as np

# %%
shark_df = pd.read_csv("GSAF5.csv", engine="python")

# %%
shark_df
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
shark_df.columns
shark_df.shape
# Out:
# (5992, 24)

# %%
shark_df.isnull().sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
shark_df[(df["Unnamed: 22"].isnull()==False)]
# Out:
#      Case Number       Date  Year        Type Country        Area  \
# 1247  2006.06.18  18-Jun-06  2006  Unprovoked  BRAZIL  Pernambuco
#
#                             Location       Activity                     Name  \
# 1247  Punta Del Chifre Beach, Olinda  Body boarding  Humberto Pessoa Batista
#
#      Sex      ...     Species  Investigator or Source                     pdf  \
# 1247    M     ...          NaN     globalsurfnews.com  2006.06.18-Batista.pdf
#
#                                            href formula  \
# 1247  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 1247  http://sharkattackfile.net/spreadsheets/pdf_di...    2006.06.18
#
#      Case Number.2 original order   Unnamed: 22 Unnamed: 23
# 1247    2006.06.18           4746  stopped here         NaN
#
# [1 rows x 24 columns]

# %%
shark_df[(df["Unnamed: 23"].isnull()==False)]
# Out:
#      Case Number         Date  Year      Type    Country             Area  \
# 4182  1952.07.13    13-Jul-52  1952  Provoked        USA       California
# 5585  1879.03.10  10-Mar-1879  1879   Invalid  AUSTRALIA  New South Wales
#
#                          Location  \
# 4182  San Diego, San Diego County
# 5585                 Near Sydney
#
#                                            Activity  \
# 4182                                        Fishing
# 5585  The steamship Bonnie Dundee lost in collision
#
#                                                    Name Sex        ...         \
# 4182  Gerald Howard, on board sportsfishing boat Ter...    M       ...
# 5585                     Cabin boy of the Bonnie Dundee    M       ...
#
#      Species   Investigator or Source                           pdf  \
# 4182      NaN  L.A. Times, 7/14/1952          1952.07.13-Howard.pdf
# 5585      NaN         Star, 3/22/1879  1879.03.10-Bonnie-Dundee.pdf
#
# ...

# %%
#Eliminar las dos ultimas columnas 
shark_df = shark_df.drop(["Unnamed: 22","Unnamed: 23"], axis=1)

# %%
shark_df
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
a= (shark_df["Activity"].tolist())
print(set(a))
# Out:
# {nan, 'Catching sardines', 'Hiking on the beach', "Holding shark's tail ", 'Dropping anchor', 'Body Boarding', 'Spearfishing, had fish on his spear', 'Taking catch from a fish weir in which the shark was snared', 'Standing alongside surfboard', 'Diving. Shark �swallowed� his hand, so he threw his other around the shark and went �shark-back riding� for 30 yards until the shark opened its jaws', 'Boat exploded', 'Attempting to escape by swimming to shore', 'Shipwrecked Persian Fleet', 'Standing on sandbank', 'Fishing for tarpon', 'Air disaster', 'Wade Fishing', 'Netting sharks', 'Oystering', "During a shark fishing tournament, the 18' Boatem was capsized by waves, throwing 3 men into the water ", 'Helping angler land a shark', 'British ship Macedon was thrown on her beam ends by a sudden squall', 'Free diving / spearfishing, ', 'Floating in tube', '"Swimming vigorously"', 'ship William Penn grounded & broke apart', 'Fishing for the shark that killed George Lundberg', 'Lobster diving us
# ...

# %%
'''pd.set_option('display.max_rows', 6000)
pd.set_option('display.max_columns', 500)'''
